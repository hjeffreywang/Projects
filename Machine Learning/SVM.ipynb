# %%
# Update sklearn to prevent version mismatches
import sklearn

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
import joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Select your features (columns)

# %%
# Set and remove features. This will also be used as your x values.
target = df["koi_disposition"]
data = df.drop(["koi_disposition","koi_fpflag_nt"], axis=1)
features = data.columns
data.head(5)
# Out:
#    koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  koi_period_err1  \
# 0              0              0              0   54.418383     2.479000e-04
# 1              1              0              0   19.899140     1.490000e-05
# 2              1              0              0    1.736952     2.630000e-07
# 3              0              0              0    2.525592     3.760000e-06
# 4              0              0              0    4.134435     1.050000e-05
#
#    koi_period_err2  koi_time0bk  koi_time0bk_err1  koi_time0bk_err2  \
# 0    -2.479000e-04   162.513840          0.003520         -0.003520
# 1    -1.490000e-05   175.850252          0.000581         -0.000581
# 2    -2.630000e-07   170.307565          0.000115         -0.000115
# 3    -3.760000e-06   171.595550          0.001130         -0.001130
# 4    -1.050000e-05   172.979370          0.001900         -0.001900
#
#    koi_impact  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# ...

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=0)

# %%
X_train.head()
# Out:
#       koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3053              0              0              0    1.867994
# 3214              0              0              0    7.429932
# 5553              1              0              0   11.702204
# 6889              0              0              0  358.743180
# 161               0              0              0    2.688899
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3053     1.020000e-05    -1.020000e-05   133.229860          0.005050
# 3214     1.552000e-04    -1.552000e-04   138.770100          0.017100
# 5553     4.220000e-07    -4.220000e-07   139.431265          0.000030
# 6889     4.849000e-02    -4.849000e-02   150.554000          0.064300
# 161      1.900000e-07    -1.900000e-07   170.102090          0.000056
#
#       koi_time0bk_err2  koi_impact  ...  koi_steff_err2  koi_slogg  \
# 3053         -0.005050       0.173  ...            -147      4.568
# ...

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)

X_train = X_minmax.transform(X_train)
X_test = X_minmax.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.svm import SVC 

SVC = SVC(kernel='poly')
SVC.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {SVC.score(X_train, y_train)}")
print(f"Testing Data Score: {SVC.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7800877360289911
# Testing Data Score: 0.7688787185354691

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
# Train the model with GridSearch
from sklearn.model_selection import GridSearchCV
parameters = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.005]}
grid = GridSearchCV(SVC, parameters, verbose=3, n_jobs=-1)
#n_jobs for faster processing

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  38 out of  45 | elapsed:    4.9s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    5.0s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='poly', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.005]},
# ...

# %%
print(f"Training Data Score: {grid.best_params_}")
print(f"Training Data Score: {grid.best_score_}")
# Out:
# Training Data Score: {'C': 1, 'gamma': 0.0001}
# Training Data Score: 0.5029564689016801

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'Model/SVC.sav'
joblib.dump(SVC, filename)
# Out:
# ['Model/SVC.sav']
